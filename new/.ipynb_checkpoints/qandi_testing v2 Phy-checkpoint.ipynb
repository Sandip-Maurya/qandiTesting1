# %%
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from datetime import datetime
import pandas as pd
import os, re, time, json, random
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException

# %%
# starts browser
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.implicitly_wait(10)

# %%
mobile = '9910737626'
login_url = 'https://app.qandi.com/login'
mobile_email_xp = '//*[@id="mobile_num"]'
next_btn_xp = '//*[@id="mobile-input-btn"]'
enter_otp_xp = '//*[@id="otp_num"]'
verify_xp = '//*[@id="otp-verify-btn"]'
custom_url = 'https://app.qandi.com/exam_custom'

sub_xp = '//*[@id="Mathematics_btn"]'
save_and_next_xp_f = '//*[@id="question_section"]/div[3]/a[1]'
save_and_next_xp_o = '//*[@id="question_section"]/div/div[3]/a[1]'
q_type_xp = '//*[@id="question_section"]/div/div[1]/span'

wait = 3
prob = 0.9 # for toppers

# %%
q_data = pd.read_excel('all_live_questions.xlsx')
q_data[:1]
# Out:
#    question_id  class_id  subject_id  unit_id  chapter_id  topic_id  \
# 0         2055         1           1     15.0       294.0    3470.0
#
#    major_concept_id  difficulty_level  template_type  \
# 0            2807.0              14.0            2.0
#
#                                              answers
# 0  {"3":"<p><math xmlns=\"http:\/\/www.w3.org\/19...

# %%
ans = re.sub('[\[\]\"]', '', q_data[q_data['question_id']==181299]['answers'].values[0])
ans
# Out:
# '2'

# %%
# Login to qandi

def login():
    driver.get(login_url)

    driver.find_element(By.ID, 'mobile_num').send_keys(mobile)
    next_btn_elm = driver.find_element(By.ID, 'mobile-input-btn')

    try:
        next_btn_elm.click()
        enter_otp_elm = driver.find_element(By.ID, 'otp_num')
    except:
        try:
            driver.execute_script("arguments[0].click();", next_btn_elm)
            enter_otp_elm = driver.find_element(By.ID, 'otp_num')
        except:
            print('Not able to login')

    otp = input('Please input otp and then press enter to continue:')
    enter_otp_elm.send_keys(otp)
    verify_elm = driver.find_element(By.ID, 'otp-verify-btn')

    try:
        verify_elm.click()
    except:
        driver.execute_script("arguments[0].click();", verify_elm)
    return

# %%
login()
# Out:
# Please input otp and then press enter to continue: 80197

# %%
def get_topic_ids(chp_id):
    chap_box_content = driver.find_element(By.ID, f'chapter_box_{chp_id}').get_attribute('innerHTML')
    topic_ids = re.findall(r'id="chpt_topic_(\d+)"', chap_box_content)
    topic_ids = [int(i) for i in topic_ids]
    return topic_ids

# %%
def get_curr_q_id():
    curr_q_xp = '//*[@id="current_question"]'
    curr_q_elm = driver.find_element(By.XPATH, curr_q_xp)
    curr_q_id = curr_q_elm.get_attribute('value')    
    return int(curr_q_id)
# get_curr_q_id()

# %%
def get_corr_options(q_id, prob):
    ans_text = q_data[q_data['question_id']==q_id]['answers'].values[0]
    ans_text_dict = json.loads(ans_text)
    corr_options = list(ans_text_dict.keys())
    corr_options = [int(i) for i in corr_options]
    incorr_options = [i for i in range(1,5) if i not in corr_options]
    if random.random() > prob:
        corr_options[0] = incorr_options[0]
    return corr_options

# %%
def do_question(o_xps, save_and_next_xp, wait, curr_q_id):
    # choose option
    for o_xp in o_xps:
        o_xp_elm = driver.find_element(By.XPATH, o_xp)
        time.sleep(wait)
        # o_xp_elm.click()
        driver.execute_script("arguments[0].click();", o_xp_elm)
    
    # click save and next after wait time is over
    # time.sleep(wait)
    save_and_next_elm = driver.find_element(By.XPATH, save_and_next_xp)
    time.sleep(1)
    driver.execute_script("arguments[0].click();", save_and_next_elm)
    
    time.sleep(1)
    curr_id_temp = get_curr_q_id()
    # print(curr_id_temp, curr_q_id)
    if curr_id_temp == curr_q_id:
        time.sleep(1)
        save_and_next_elm.click()
    return

# %%
get_curr_q_id()
# Out:
# 152121

# %%
corr_option = 1
curr_q_id = 152121
o_xp_o = f'//*[@id="question_section"]/div/div[2]/div[2]/div[{corr_option}]/div/label'
o_xps = []
o_xps.append(o_xp_o)

do_question(o_xps, save_and_next_xp_o, wait, curr_q_id)
# Out:
# 152121 152121

# %%
def do_question_num(ans, save_and_next_xp, wait, curr_q_id):
    
    num_ans_box_xp = f'//*[@id="quest_option_{curr_q_id}"]'
    num_ans_box_elm = driver.find_element(By.XPATH, num_ans_box_xp)
    num_ans_box_elm.send_keys(ans)
    time.sleep(wait)
    save_and_next_elm = driver.find_element(By.XPATH, save_and_next_xp)
    time.sleep(1)
    driver.execute_script("arguments[0].click();", save_and_next_elm)

# %%
ans = 1.2
curr_q_id = 181299
save_and_next_xp = '//*[@id="question_section"]/div/div[3]/a[1]'
do_question_num(ans, save_and_next_xp, wait, curr_q_id)

# %%
# Attempt Topic test

def do_topic_test():
    
    # Do first question
    curr_q_id = get_curr_q_id()
    q_type_elm = driver.find_element(By.XPATH, q_type_xp)
    q_type = q_type_elm.get_attribute('innerText')
    
    if q_type == 'NUMERICAL':
        ans = re.sub('[\[\]\"]', '', q_data[q_data['question_id']==curr_q_id]['answers'].values[0])
        do_question_num(ans, save_and_next_xp_f, wait, curr_q_id)
    else:
        corr_options = get_corr_options(curr_q_id, prob)
        count = 0
        o_xps = []
        for corr_option in corr_options:
            o_xp_f = f'//*[@id="question_section"]/div[2]/div[2]/div[{corr_option}]/div/label'
            o_xps.append(o_xp_f)

        do_question(o_xps, save_and_next_xp_f, wait, curr_q_id)
        
    count += 1
    print(f'No. of questions done: {count}')

    # Do other questions
    sub_test_xp = '//*[@id="bt-modal-confirm_over"]'
    sub_test_elm = driver.find_element(By.XPATH, sub_test_xp)
    test_end_condition = sub_test_elm.get_attribute('innerText')

    while test_end_condition != 'SUBMIT TEST':
        
        curr_q_id = get_curr_q_id()
        q_type_elm = driver.find_element(By.XPATH, q_type_xp)
        q_type = q_type_elm.get_attribute('innerText')
        if q_type == 'NUMERICAL':
            ans = re.sub('[\[\]\"]', '', q_data[q_data['question_id']==curr_q_id]['answers'].values[0])
            do_question_num(ans, save_and_next_xp_o, wait, curr_q_id)
        
        else:
            o_xps = []
            try:
                corr_options = get_corr_options(curr_q_id, prob)
                for corr_option in corr_options:
                    o_xp_o = f'//*[@id="question_section"]/div/div[2]/div[2]/div[{corr_option}]/div/label'
                    o_xps.append(o_xp_o)
                time.sleep(1)
                do_question(o_xps, save_and_next_xp_o, wait, curr_q_id)
            except StaleElementReferenceException:
                input('do question and press enter')

        count += 1
        print(f'No. of questions done: {count}')
        try:
            sub_test_elm = driver.find_element(By.XPATH, sub_test_xp)
            test_end_condition = sub_test_elm.get_attribute('innerText')
        except:
            break

    time.sleep(1)
    driver.execute_script("arguments[0].click();", sub_test_elm)
    # driver.save_screenshot(os.path.join(os.getcwd(),'botTestOutput',f'{Subject[0]}_{Topic}.png'))
    return

# %%
# For maths

driver.get(custom_url)

math_list_innerHTML = driver.find_element(By.ID,'Mathematics_list').get_attribute('innerHTML')
math_chp_ids = re.findall(r'id="chapter_box_(\d+)"', math_list_innerHTML)
math_chp_ids = [int(i) for i in math_chp_ids]


for chp_id in math_chp_ids[3:]:
    
    chp_expand_elm = driver.find_element(By.ID, f"expand_topic_{chp_id}")
    time.sleep(0.5)
    driver.execute_script("arguments[0].click();", chp_expand_elm)
    time.sleep(1)
    topic_ids = get_topic_ids(chp_id)
    
    for topic_id in topic_ids:
        
        topic_select_elm = driver.find_element(By.ID, f"chpt_topic_{topic_id}")
        time.sleep(0.5)
        driver.execute_script("arguments[0].click();", topic_select_elm)
        take_test_for_sel_topic_elm = driver.find_element(By.XPATH, '//*[@id="topic_custom_footer"]/button')
        time.sleep(0.5)
        driver.execute_script("arguments[0].click();", take_test_for_sel_topic_elm)
        time.sleep(1)
        go_for_it_elm = driver.find_element(By.XPATH, '//*[@id="goto-exam-btn"]')
        time.sleep(0.5)
        driver.execute_script("arguments[0].click();", go_for_it_elm)
        try:
            do_topic_test()
        except :
            SUB_TEST_elm = driver.find_element(By.ID, 'bt-modal-confirm_over')
            time.sleep(1)
            SUB_TEST_elm.click()
        time.sleep(1)
        driver.get(custom_url)
        time.sleep(1)
        chp_expand_elm = driver.find_element(By.ID, f"expand_topic_{chp_id}")
        time.sleep(0.5)
        driver.execute_script("arguments[0].click();", chp_expand_elm)
        time.sleep(1)
# Out:
# 165960 165987
# No. of questions done: 1
# 29064 165960
# No. of questions done: 2
# 45402 29064
# No. of questions done: 3
# 45402 45402
# 29114 28729
# No. of questions done: 1
# 29114 29114
# 154992 28821
# No. of questions done: 1
# 163360 154992
# No. of questions done: 2
# 29254 163360
# No. of questions done: 3
# 29399 29254
# No. of questions done: 4
# 152082 29399
# No. of questions done: 5
# 153296 152082
# No. of questions done: 6
# 29042 153296
# No. of questions done: 7
# 183460 29042
# No. of questions done: 8
# No. of questions done: 9
# No. of questions done: 10
# 28814 28491
# No. of questions done: 1
# 167033 28814
# No. of questions done: 2
# 152077 167033
# No. of questions done: 3
# 184723 152077
# No. of questions done: 4
# No. of questions done: 5
# No. of questions done: 6
# 29234 28314
# No. of questions done: 1
# 28905 29234
# No. of questions done: 2
# 155398 28905
# No. of questions done: 3
# 181533 155398
# No. of questions done: 4
# No. of questions done: 5
# No. of questions done: 6
# 16196 39717
# No. of questions done: 1
# 171314 16196
# No. of questions done: 2
# 184561 171314
# No. of questions done: 3
# No. of questions done: 4
# No. of questions done: 5
# 45221 2439
# No. of questions done: 1
# 166914 45221
# No. of questions done: 2
# 45540 166914
# No. of questions done: 3
# 166898 45540
# No. of questions done: 4
# 42098 166898
# No. of questions done: 5
# 40693 42098
# No. of questions done: 6
# 152020 40693
# No. of questions done: 7
# 151977 152020
# No. of questions done: 8
# 42173 151977
# No. of questions done: 9
# 154499 42173
# No. of questions done: 10
# 159075 154499
# No. of questions done: 11
# 159085 159075
# No. of questions done: 12
# 152014 159085
# No. of questions done: 13
# No. of questions done: 21
# 173100 173137
# No. of questions done: 22
# 153083 173100
# No. of questions done: 23
# 160695 153083
# No. of questions done: 24
# 160700 160695
# No. of questions done: 25
# 151489 160700
# No. of questions done: 26
# 161100 151489
# No. of questions done: 27
# 173162 161100
# No. of questions done: 28
# 151533 173162
# No. of questions done: 29
# 151558 151533
# No. of questions done: 30
# 151567 151558
# No. of questions done: 31
# 151592 151567
# No. of questions done: 32
# 152605 151592
# No. of questions done: 33
# 153124 152605
# No. of questions done: 34
# 44647 153124
# No. of questions done: 35
# 44707 44647
# No. of questions done: 36
# 44817 44707
# No. of questions done: 37
# 151459 44817
# No. of questions done: 38
# 151471 151459
# No. of questions done: 39
# 151490 151471
# No. of questions done: 40
# 151564 151490
# No. of questions done: 41
# 151578 151564
# No. of questions done: 42
# 151591 151578
# No. of questions done: 43
# 151618 151591
# No. of questions done: 44
# 44266 151618
# No. of questions done: 45
# 151639 44266
# No. of questions done: 46
# 151769 151639
# No. of questions done: 47
# 44668 151769
# No. of questions done: 48
# 184154 44668
# No. of questions done: 49
# No. of questions done: 50
# No. of questions done: 51
# 43973 16001
# No. of questions done: 1
# 173171 43973
# No. of questions done: 2
# 44643 173171
# No. of questions done: 3
# 44000 44643
# No. of questions done: 4
# 44726 44000
# No. of questions done: 5
# 44439 44726
# No. of questions done: 6
# 151463 44439
# No. of questions done: 7
# 153726 151463
# No. of questions done: 8
# 153729 153726
# No. of questions done: 9
# 153730 153729
# No. of questions done: 10
# 153741 153730
# No. of questions done: 11
# 153765 153741
# No. of questions done: 12
# 160716 153765
# No. of questions done: 13
# 160687 160716
# No. of questions done: 14
# 160706 160687
# No. of questions done: 15
# 183272 160706
# No. of questions done: 16
# No. of questions done: 17
# No. of questions done: 18
# 159470 39506
# No. of questions done: 1
# 28427 159470
# No. of questions done: 2
# No. of questions done: 3
# No. of questions done: 4
# 159463 39658
# No. of questions done: 1
# 171432 159463
# No. of questions done: 2
# 159453 171432
# No. of questions done: 3
# 39970 159453
# No. of questions done: 4
# 181558 39970
# No. of questions done: 5
# No. of questions done: 6
# No. of questions done: 7
# 155242 29564
# No. of questions done: 1
# 173839 155242
# No. of questions done: 2
# 39654 173839
# No. of questions done: 3
# 160010 39654
# No. of questions done: 4
# 160032 160010
# No. of questions done: 5
# 160032 160032
# do question and press enter
# No. of questions done: 6
# 151627 152564
# No. of questions done: 1
# 152560 151627
# No. of questions done: 2
# 151632 152560
# No. of questions done: 3
# 41599 151632
# No. of questions done: 4
# 41599 41599

# %%
math_chp_ids[:2]
# Out:
# [324, 313]

# %%
topic_ids[:2]
# Out:
# []

# %%
chp_id = 313
get_topic_ids(chp_id)
# Out:
# [3769, 3772, 3771, 3770]

# %%
get_curr_q_id()
# Out:
# 181299

# %%
q_type_elm = driver.find_element(By.XPATH, q_type_xp)
q_type = q_type_elm.get_attribute('innerText')
q_type
# Out:
# 'NUMERICAL'

# %%
num_ans_box_xp = '//*[@id="quest_option_181299"]'
num_ans_box_elm = driver.find_element(By.XPATH, num_ans_box_xp)
num_ans_box_elm.send_keys('1')

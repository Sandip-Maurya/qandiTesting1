# %%
import numpy as np
import matplotlib.pyplot as plt

total_weeks = 100
total_topics = 440

# %%
joining_weeks = int(input('Please input joining week (A value between 1 to 100): '))
current_week = int(input('Please input current week (A value between 1 to 100 but it should be greater than joining week): '))
total_topics_covered = int(input('Please input total topics covered till now (A value between 1 to 440): '))
# Out:
# Please input joining week (A value between 1 to 100) 2
# Please input current week (A value between 1 to 100 but it should be greater than joining week)  10
# Please input total topics covered till now (A value between 1 to 440) 10

# %%
x = np.linspace(0, current_week-joining_weeks, 10)
x
# Out:
# array([0.        , 0.88888889, 1.77777778, 2.66666667, 3.55555556,
#        4.44444444, 5.33333333, 6.22222222, 7.11111111, 8.        ])

# %%
y_ideal =  4.5*x
y_ideal
# Out:
# array([ 0.,  4.,  8., 12., 16., 20., 24., 28., 32., 36.])

# %%
y_actual = np.linspace(0, total_topics_covered, 10)
y_actual
# Out:
# array([ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#         5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ])

# %%
joining_weeks = int(input('Please input joining week (A value between 1 to 100): '))
current_week = int(input('Please input current week (A value between 1 to 100 but it should be greater than joining week): '))
total_topics_covered = int(input('Please input total topics covered till now (A value between 1 to 440): '))

# %%
joining_weeks = int(input('Please input joining week (A value between 1 to 100): '))
current_week = int(input('Please input current week (A value between 1 to 100 but it should be greater than joining week): '))
total_topics_covered = int(input('Please input total topics covered till now (A value between 1 to 440): '))

x = np.linspace(0, current_week-joining_weeks, 10)
y_ideal =  4.5*x
y_actual = np.linspace(0, total_topics_covered, 10)


plt.plot(x, y_ideal, label = 'Ideal Progress')
plt.plot(x, y_actual, label = 'Your Progress')
plt.legend()
plt.ylabel('No. of Topics')
plt.xlabel('Time passed since joining (in weeks)')
plt.show()
# Out:
# Please input joining week (A value between 1 to 100):  1
# Please input current week (A value between 1 to 100 but it should be greater than joining week):  10
# Please input total topics covered till now (A value between 1 to 440):  40

# %%
total_weeks = 100
total_topics = 500

joining_weeks = int(input('Please input joining week (A value between 1 to 100): '))
current_week = int(input('Please input current week (A value between 1 to 100 but it should be greater than joining week): '))
total_topics_covered = int(input('Please input total topics covered till now (A value between 1 to 440): '))

x = np.linspace(0, current_week-joining_weeks, 10)
y_ideal =  4.5*x
y_actual = np.linspace(0, total_topics_covered, 10)

topics_covered_by_you = y_actual[-1]
topics_which_should_have_been_covered = y_ideal[-1]

plt.plot(x, y_ideal, label = 'Ideal Progress')
plt.plot(x, y_actual, label = 'Your Progress')
plt.legend()
plt.title(f'Progress Graph \ntopics_which_should_have_been_covered: {int(topics_which_should_have_been_covered)}\ntopics_covered_by_you: {int(topics_covered_by_you)}')
plt.ylabel('No. of Topics')
plt.xlabel('Time passed since joining (in weeks)')
plt.show()
int(topics_which_should_have_been_covered)
# Out:
# Please input joining week (A value between 1 to 100):  5
# Please input current week (A value between 1 to 100 but it should be greater than joining week):  30
# Please input total topics covered till now (A value between 1 to 440):  100
# 112

# %%
# !jupyter-lab --version
# Out:
# 3.2.1

# %%
# !jupyter --version
# Out:
# Selected Jupyter core packages...
# IPython          : 7.29.0
# ipykernel        : 6.4.1
# ipywidgets       : not installed
# jupyter_client   : 7.0.6
# jupyter_core     : 4.9.1
# jupyter_server   : 1.4.1
# jupyterlab       : 3.2.1
# nbclient         : 0.5.3
# nbconvert        : not installed
# nbformat         : 5.1.3
# notebook         : 6.4.6
# qtconsole        : not installed
# traitlets        : 5.1.1

# %%
# !jupyter-lab --version
# Out:
# 3.0.0

# %%
# !jupyter --version
# Out:
# Selected Jupyter core packages...
# IPython          : 8.3.0
# ipykernel        : 6.9.1
# ipywidgets       : not installed
# jupyter_client   : 7.2.2
# jupyter_core     : 4.10.0
# jupyter_server   : 1.4.1
# jupyterlab       : 3.0.0
# nbclient         : 0.5.13
# nbconvert        : 6.4.4
# nbformat         : 5.3.0
# notebook         : 6.4.11
# qtconsole        : not installed
# traitlets        : 5.1.1

# %%
pip install jupyterlab-github
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2>=2.10->jupyterlab~=3.0->jupyterlab-github) (2.0.1)
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\anaconda3\lib\site-packages)

# %%
# !jupyter server extension enable jupyterlab_github
# Out:
# Enabling: jupyterlab_github
# - Writing config: C:\Users\USER\anaconda3\etc\jupyter
#     - Validating jupyterlab_github...
#       jupyterlab_github 3.0.1 ok
#     - Extension successfully enabled.

# %%
# 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

! c.GitHubConfig.access_token = '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'
# Out:
# 'c.GitHubConfig.access_token' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !jupyter notebook --generate-config
# Out:
# Writing default config to: C:\Users\USER\.jupyter\jupyter_notebook_config.py
